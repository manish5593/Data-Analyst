# %% [markdown]
# ## Common Programmatic Assessments in pandas
# ### Gather

# %%
import pandas as pd

# %%
patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')
adverse_reactions = pd.read_csv('adverse_reactions.csv')

# %% [markdown]
# ### Assess
# These are the programmatic assessment methods in pandas that you will probably use most often:
#
# * .head (DataFrame and Series)
# * .tail (DataFrame and Series)
# * .sample (DataFrame and Series)
# * .info (DataFrame only)
# * .describe (DataFrame and Series)
# * .value_counts (Series only)
# * Various methods of indexing and selecting data (.loc and bracket notation with/without boolean indexing, also .iloc)
#
# Try them out below and keep their results in mind. Some will come in handy later in the lesson.
#
# Check out the [pandas API reference](https://pandas.pydata.org/pandas-docs/stable/api.html) for detailed usage information.

# %% [markdown]
# Try `.head` and `.tail` on the `patients` table.

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# 1       PamelaSHill@cuvox.de+1 (217) 569-3204   4/3/1967   118.8      66  19.2
# 2            402-363-6804JaeMDebord@gustr.com  2/19/1980   177.8      71  24.8
# 3  PhanBaLiem@jourrapide.com+1 (732) 636-8246  7/26/1951   220.9      70  31.7
# 4             334-515-7487TimNeudorf@cuvox.de  2/18/1928   192.3      27  26.1

# %%
patients.tail()
# Out:
#      patient_id assigned_sex given_name      surname  \
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                       address           city     state  zip_code  \
# 498       2530 Victoria Court   Milton Mills        ME    3852.0
# 499  494 Clarksburg Park Road         Sedona        AZ   86341.0
# 500         649 Nutter Street  Overland Park        MO   64110.0
# 501  3652 Boone Crockett Lane        Seattle        WA   98109.0
# 502         2778 North Avenue           Burr  Nebraska   68324.0
#
#            country                                          contact  \
# 498  United States      207-477-0579MustafaLindstrom@jourrapide.com
# 499  United States               928-284-4492RumanBisliev@gustr.com
# 500  United States            816-223-6007JinkedeKeizer@teleworm.us
# 501  United States  ChidaluOnyekaozulu@jourrapide.com1 360 443 2060
# 502  United States             PatrickGersten@rhyta.com402-848-4923
#
#      birthdate  weight  height   bmi
# 498  4/10/1959   181.1      72  24.6
# 499  3/26/1948   239.6      70  34.4
# 500  1/13/1971   171.2      67  26.8
# 501  2/13/1952   176.9      67  27.7
# 502   5/3/1954   138.2      71  19.3

# %% [markdown]
# Try `.sample` on the `treatments` table.

# %%
treatments.sample()
# Out:
#     given_name    surname    auralin novodra  hba1c_start  hba1c_end  \
# 51  kristoffer  martinsen  29u - 37u       -         9.18       8.64
#
#     hba1c_change
# 51           NaN

# %% [markdown]
# Try `.info` on the `treatments` table.

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
# given_name      280 non-null object
# surname         280 non-null object
# auralin         280 non-null object
# novodra         280 non-null object
# hba1c_start     280 non-null float64
# hba1c_end       280 non-null float64
# hba1c_change    171 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %% [markdown]
# Try `.describe` on the `patients` table.

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
adverse_reactions.describe()
# Out:
#        given_name  surname adverse_reaction
# count          34       34               34
# unique         34       33                6
# top     abdul-nur  johnson     hypoglycemia
# freq            1        2               19

# %% [markdown]
# Try `.value_counts` on the *adverse_reaction* column of the `adverse_reactions` table.

# %%
adverse_reactions['adverse_reaction'].value_counts()
# Out:
# hypoglycemia                 19
# injection site discomfort     6
# headache                      3
# nausea                        2
# cough                         2
# throat irritation             2
# Name: adverse_reaction, dtype: int64

# %% [markdown]
# Try selecting the records in the `patients` table for patients that are from the *city* New York.

# %%
patients[patients.state == 'NY']
# Out:
#      patient_id assigned_sex    given_name     surname  \
# 22           23         male        Manchu          Su
# 64           65         male        Jaakko   Eskelinen
# 84           85       female         Nương          Vũ
# 129         130       female       Rebecca    Jephcott
# 148         149       female        Riëtte   Scheltens
# 152         153         male   Christopher    Woodward
# 188         189         male         Søren    Sørensen
# 192         193       female          Jade      Parker
# 213         214       female    Onyemaechi   Onwughara
# 215         216         male          John         Doe
# 229         230         male          John         Doe
# 237         238         male          John         Doe
# 244         245         male          John         Doe
# 247         248         male        Tuukka  Leppäluoto
# 251         252         male          John         Doe
# 263         264       female         Julia    Carvalho
# 277         278         male          John         Doe
# 301         302       female  Onyekachukwu      Obinna
# 346         347       female         Helen       Luwam
# 442         443         male       Ananías    Enríquez
# 450         451         male       Clinton      Miller
# 461         462         male        Cannan     Cabrera
#
#                           address  city state  zip_code        country  \
# 22                1092 Deans Lane  York    NY   10570.0  United States
# 64                4324 Oak Street  York    NY   13221.0  United States
# 84            465 Southern Street  York    NY   10001.0  United States
# 129              989 Wayback Lane  York    NY   10004.0  United States
# 148            4473 Church Street  York    NY   11227.0  United States
# 152          3450 Southern Street  York    NY   10004.0  United States
# 188              2397 Bell Street  York    NY   10011.0  United States
# 192    2957 Feathers Hooves Drive  York    NY   11530.0  United States
# 213             685 Duncan Avenue  York    NY   10013.0  United States
# 215               123 Main Street  York    NY   12345.0  United States
# 229               123 Main Street  York    NY   12345.0  United States
# 237               123 Main Street  York    NY   12345.0  United States
# 244               123 Main Street  York    NY   12345.0  United States
# 247            1886 Bicetown Road  York    NY   10011.0  United States
# 251               123 Main Street  York    NY   12345.0  United States
# 263             3662 Shinn Street  York    NY   10036.0  United States
# 277               123 Main Street  York    NY   12345.0  United States
# 301            2970 Forest Avenue  York    NY   10004.0  United States
# 346  2687 Hinkle Deegan Lake Road  York    NY   13904.0  United States
# 442           2924 Stanley Avenue  York    NY   11530.0  United States
# 450           901 Southern Street  York    NY   11576.0  United States
# 461           2102 Geraldine Lane  York    NY   10014.0  United States
#
#                                                contact   birthdate  weight  \
# 22                     914-745-6108ManchuSu@einrot.com   1/19/1936   130.7
# 64      JaakkoEskelinen@superrito.com+1 (315) 362-5858   2/26/1971   163.7
# 84                  VuCamNuong@fleckens.hu516-720-5094    2/1/1981   138.2
# 129            631-370-7406RebeccaJephcott@armyspy.com    8/1/1966   203.3
# 148             718-418-0766RietteScheltens@dayrep.com   9/30/1940   198.4
# 152  ChristopherWoodward@jourrapide.com+1 (516) 630...    9/4/1984   212.2
# 188            SrenSrensen@superrito.com1 212 201 3108  12/31/1942   157.1
# 192               631-704-6487JadeParker@superrito.com   6/19/1927   188.8
# 213         917-622-9142OnyemaechiOnwughara@einrot.com    3/8/1989   131.1
# 215                        johndoe@email.com1234567890    1/1/1975   180.0
# 229                        johndoe@email.com1234567890    1/1/1975   180.0
# 237                        johndoe@email.com1234567890    1/1/1975   180.0
# 244                        johndoe@email.com1234567890    1/1/1975   180.0
# 247           917-408-8855TuukkaLeppaluoto@teleworm.us    3/7/1978   211.0
# 251                        johndoe@email.com1234567890    1/1/1975   180.0
# 263  JuliaAzevedoCarvalho@superrito.com+1 (212) 782...   4/11/1931   171.8
# 277                        johndoe@email.com1234567890    1/1/1975   180.0
# 301         OnyekachukwuObinna@teleworm.us646-982-6609   1/24/1997   154.7
# 346                  HelenLuwam@dayrep.com607-206-1483    7/6/1946   166.3
# 442     516-512-4875AnaniasEnriquezMontoya@armyspy.com   7/23/1959   169.0
# 450               516-626-8021ClintonKMiller@rhyta.com   8/16/1985   195.4
# 461     646-289-4177CannanCabreraOrdonez@superrito.com  10/12/1980   209.7
#
#      height   bmi
# 22       65  21.7
# 64       68  24.9
# 84       63  24.5
# 129      65  33.8
# 148      67  31.1
# 152      66  34.2
# 188      67  24.6
# 192      63  33.4
# 213      69  19.4
# 215      72  24.4
# 229      72  24.4
# 237      72  24.4
# 244      72  24.4
# 247      73  27.8
# 251      72  24.4
# 263      61  32.5
# 277      72  24.4
# 301      65  25.7
# 346      60  32.5
# 442      72  22.9
# 450      74  25.1
# 461      71  29.2
